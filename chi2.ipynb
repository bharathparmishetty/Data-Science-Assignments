# %%
#null hypothesis= there is no significance difference between satisfaction level and type of a device
#alternate hypothesis=there is a significance difference between satisfaction level and type of a device

# %%
data={"satisfaction":["very satisfied","satisfied","neutral","unsatisfied","very unsatisfied"],
      "smart thermostat":[50,80,60,30,20],
      "smart light":[70,100,90,50,50]}
data
# Out:
# {'satisfaction': ['very satisfied',
#   'satisfied',
#   'neutral',
#   'unsatisfied',
#   'very unsatisfied'],
#  'smart thermostat': [50, 80, 60, 30, 20],
#  'smart light': [70, 100, 90, 50, 50]}

# %%
df=pd.DataFrame(data)
df
# Out:
#        satisfaction  smart thermostat  smart light
# 0    very satisfied                50           70
# 1         satisfied                80          100
# 2           neutral                60           90
# 3       unsatisfied                30           50
# 4  very unsatisfied                20           50

# %%
from scipy import stats
from scipy.stats import chi2_contingency,chi2

# %%
stats.chi2_contingency(np.array([[50,70],[80,100],[60,90],[30,50],[20,50]]))
# Out:
# Chi2ContingencyResult(statistic=5.638227513227513, pvalue=0.22784371130697179, dof=4, expected_freq=array([[ 48.,  72.],
#        [ 72., 108.],
#        [ 60.,  90.],
#        [ 32.,  48.],
#        [ 28.,  42.]]))

# %%
chi2_critical=stats.chi2.ppf(0.975,4)
print("critical valve:",chi2_critical)
# Out:
# critical valve: 11.143286781877796

# %%
#chi2 statistical  value is lessthan chi2 critical valve
#Accept null hypothesis
